# %%
import pandas as pd

# %%
#df es data frame
df = pd.read_csv('imdb_top_1000.csv')

# %%
print(df['Star1'])
# Out:
# 0            Tim Robbins
# 1          Marlon Brando
# 2         Christian Bale
# 3              Al Pacino
# 4            Henry Fonda
#              ...
# 995       Audrey Hepburn
# 996     Elizabeth Taylor
# 997       Burt Lancaster
# 998    Tallulah Bankhead
# 999         Robert Donat
# Name: Star1, Length: 1000, dtype: object

# %%
df[df.Released_Year=='2000']
# Out:
#                                            Poster_Link  \
# 39   https://m.media-amazon.com/images/M/MV5BMDliMm...
# 69   https://m.media-amazon.com/images/M/MV5BZTcyNj...
# 96   https://m.media-amazon.com/images/M/MV5BMTA2ND...
# 97   https://m.media-amazon.com/images/M/MV5BOTdiNz...
# 160  https://m.media-amazon.com/images/M/MV5BMGMzZj...
# 244  https://m.media-amazon.com/images/M/MV5BMjQxMW...
# 253  https://m.media-amazon.com/images/M/MV5BYjZjOD...
# 384  https://m.media-amazon.com/images/M/MV5BNDVkYW...
# 512  https://m.media-amazon.com/images/M/MV5BMTYxMD...
# 514  https://m.media-amazon.com/images/M/MV5BMzY1Zj...
# 641  https://m.media-amazon.com/images/M/MV5BMTI1ND...
# 644  https://m.media-amazon.com/images/M/MV5BYThkMz...
# 645  https://m.media-amazon.com/images/M/MV5BNDdhMz...
# 647  https://m.media-amazon.com/images/M/MV5BN2Y5ZT...
# 793  https://m.media-amazon.com/images/M/MV5BNGY3NW...
# 796  https://m.media-amazon.com/images/M/MV5BNTIyNT...
# ...

# %%
df.Released_Year
# Out:
# 0      1994
# 1      1972
# 2      2008
# 3      1974
# 4      1957
#        ...
# 995    1961
# 996    1956
# 997    1953
# 998    1944
# 999    1935
# Name: Released_Year, Length: 1000, dtype: object

# %%
df[(df.Released_Year == '2000') | (df.Released_Year =='2010')]
# Out:
#                                            Poster_Link  \
# 8    https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 39   https://m.media-amazon.com/images/M/MV5BMDliMm...
# 69   https://m.media-amazon.com/images/M/MV5BZTcyNj...
# 90   https://m.media-amazon.com/images/M/MV5BMWE3MG...
# 96   https://m.media-amazon.com/images/M/MV5BMTA2ND...
# 97   https://m.media-amazon.com/images/M/MV5BOTdiNz...
# 141  https://m.media-amazon.com/images/M/MV5BNzgxMz...
# 145  https://m.media-amazon.com/images/M/MV5BYzhiND...
# 151  https://m.media-amazon.com/images/M/MV5BMTgxOT...
# 160  https://m.media-amazon.com/images/M/MV5BMGMzZj...
# 230  https://m.media-amazon.com/images/M/MV5BMjA5ND...
# 244  https://m.media-amazon.com/images/M/MV5BMjQxMW...
# 253  https://m.media-amazon.com/images/M/MV5BYjZjOD...
# 345  https://m.media-amazon.com/images/M/MV5BMjEzMz...
# 346  https://m.media-amazon.com/images/M/MV5BMzU5Mj...
# 352  https://m.media-amazon.com/images/M/MV5BMTUyMT...
# ...

# %%
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
#Create a data base with dictionaries

dict = {'Name': ['John', 'Jane', 'Joe'],
       'Adress': ['123 Main St.', 'Birnery Ave.', 'UBC'],
       'Age': ['23', '15', '51']}
df1 = pd.DataFrame(dict)

# %%
df1
# Out:
#    Name        Adress Age
# 0  John  123 Main St.  23
# 1  Jane  Birnery Ave.  15
# 2   Joe           UBC  51

# %%
df1[df1.Name=='Jane']
# Out:
#    Name        Adress Age
# 1  Jane  Birnery Ave.  15

# %%
#Create a data base with lists

df2 = pd.DataFrame([[1,2,3,4], ['aa', 'bb', 'vv', 'cc'], [323, 135, 666, 222]])

# %%
df2
# Out:
#      0    1    2    3
# 0    1    2    3    4
# 1   aa   bb   vv   cc
# 2  323  135  666  222

# %%
#Create a data base with lists

df3 = pd.DataFrame([[1,2,3,4], ['aa', 'bb', 'vv', 'cc'], [323, 135, 666, 222]], columns=['a', 'b2', 'cc', 'dd'])

# %%
df3
# Out:
#      a   b2   cc   dd
# 0    1    2    3    4
# 1   aa   bb   vv   cc
# 2  323  135  666  222
